# %%
import pandas as pd
import os

# %%
import dask.dataframe as dd

# %%
csv_path = "/home/wergillius/Project/diffuse_differentiate/data/TFAtlas/GSE217460_210322_TFAtlas_S01-S04.csv.gz"

# %%
os.path.exists(csv_path)
# Out:
# True

# %%
df = dd.read_csv(csv_path, compression='gzip', sample=100000000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = dd.read_csv(csv_path, compression='gzip', sample=100000000)
#
# File ~/.conda/envs/GenDiff/lib/python3.8/site-packages/dask/backends.py:133, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     131 func = getattr(self, dispatch_name)
#     132 try:
# --> 133     return func(*args, **kwargs)
#     134 except Exception as e:
#     135     raise type(e)(
#     136         f"An error occurred while calling the {funcname(func)} "
#     137         f"method registered to the {self.backend} backend.\n"
#     138         f"Original Message: {e}"
#     139     ) from e
#
# ...

# %%
df.shape

# %%
idx = np.where(df.iloc[0:10,:].values != 0)[0]
idx =
